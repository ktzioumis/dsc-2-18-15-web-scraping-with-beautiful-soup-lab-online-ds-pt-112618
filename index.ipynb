# %% [markdown]
# # Web Scraping with Beautiful Soup - Lab

# %% [markdown]
# ## Introduction
#
# Now that you've read and seen some docmentation regarding the use of Beautiful Soup, its time to practice and put that to work! In this lab you'll formalize some of our example code into functions and scrape the lyrics from an artist of your choice.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Scrape Static webpages
# * Select specific elements from the DOM

# %% [markdown]
# ## Link Scraping
#
# Write a function to collect the links to each of the song pages from a given artist page.

# %%
#Starter Code

from bs4 import BeautifulSoup
import requests


url = 'https://www.azlyrics.com/a/arcticmonkeys.html' #Put the URL of your AZLyrics Artist Page here!

html_page = requests.get(url) #Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing


#The example from our lecture/reading
albums = soup.find_all("div", class_="album")
data = [] #Create a storage container
for album_n in range(len(albums)):
    #On the last album, we won't be able to look forward
    if album_n == len(albums)-1:
        cur_album = albums[album_n]
        album_songs = cur_album.findNextSiblings('a')
        for song in album_songs:
            page = song.get('href')
            title = song.text
            album = cur_album.text
            data.append((title, page, album))
    else:
        cur_album = albums[album_n]
        next_album = albums[album_n+1]
        saca = cur_album.findNextSiblings('a') #songs after current album
        sbna = next_album.findPreviousSiblings('a') #songs before next album
        album_songs = [song for song in saca if song in sbna] #album songs are those listed after the current album but before the next one!
        for song in album_songs:
            page = song.get('href')
            title = song.text
            album = cur_album.text
            data.append((title, page, album))
data[:20]
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
data
# Out:
# [("Ol' 55", '../lyrics/tomwaits/ol55.html', 'album: "Closing Time" (1973)'),
#  ("I Hope That I Don't Fall In Love With You",
#   '../lyrics/tomwaits/ihopethatidontfallinlovewithyou.html',
#   'album: "Closing Time" (1973)'),
#  ('Virginia Avenue',
#   '../lyrics/tomwaits/virginiaavenue.html',
#   'album: "Closing Time" (1973)'),
#  ('Old Shoes (& Picture Postcards)',
#   '../lyrics/tomwaits/oldshoespicturepostcards.html',
#   'album: "Closing Time" (1973)'),
#  ('Midnight Lullaby',
#   '../lyrics/tomwaits/midnightlullaby.html',
#   'album: "Closing Time" (1973)'),
#  ('Martha', '../lyrics/tomwaits/martha.html', 'album: "Closing Time" (1973)'),
#  ('Rosie', '../lyrics/tomwaits/rosie.html', 'album: "Closing Time" (1973)'),
#  ('Lonely', '../lyrics/tomwaits/lonely.html', 'album: "Closing Time" (1973)'),
#  ('Ice Cream Man',
#   '../lyrics/tomwaits/icecreamman.html',
#   'album: "Closing Time" (1973)'),
#  ('Little Trip To Heaven (On The Wings Of Your Love)',
# ...

# %%
data[0][1].replace('..','')
# Out:
# '/lyrics/tomwaits/ol55.html'

# %%
new_link='https://www.azlyrics.com'+data[0][1].replace('..','')
# Out:
# https://www.azlyrics.com/lyrics/tomwaits/ol55.html

# %% [markdown]
# ## Text Scraping
# Write a secondary function that scrapes the lyrics for each song page.

# %%
#Remember to open up the webpage in a browser and control-click/right-click and go to inspect!
from bs4 import BeautifulSoup
import requests

#Example page
url = 'https://www.azlyrics.com/lyrics/tomwaits/ol55.html'


html_page = requests.get(url)
soup = BeautifulSoup(html_page.content, 'html.parser')
lyrics=soup.find(class_="col-xs-12 col-lg-8 text-center",)
lyrics2=lyrics.findAll('div')
lyrics2[6]
# Out:
# <div>
# <!-- Usage of azlyrics.com content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->
# Well my time went so quickly, I went lickety-splickly out to my old '55<br/>
# As I drove away slowly, feeling so holy, God knows, I was feeling alive.<br/>
# <br/>
# Now the sun's coming up, I'm riding with Lady Luck, freeway cars and trucks,<br/>
# Stars beginning to fade, and I lead the parade<br/>
# Just a-wishing I'd stayed a little longer,<br/>
# Oh, Lord, let me tell you that the feeling's getting stronger.<br/>
# <br/>
# And it's six in the morning, gave me no warning; I had to be on my way.<br/>
# Well there's trucks all a-passing me, and the lights are all flashing,<br/>
# I'm on my way home from your place.<br/>
# <br/>
# And now the sun's coming up, I'm riding with Lady Luck, freeway cars and trucks,<br/>
# Stars beginning to fade, and I lead the parade<br/>
# Just a-wishing I'd stayed a little longer,<br/>
# ...

# %%
lyrics3=lyrics2[6].text.replace('\n',' ').replace('\r',' ').strip()
lyrics3
# Out:
# "Well my time went so quickly, I went lickety-splickly out to my old '55 As I drove away slowly, feeling so holy, God knows, I was feeling alive.  Now the sun's coming up, I'm riding with Lady Luck, freeway cars and trucks, Stars beginning to fade, and I lead the parade Just a-wishing I'd stayed a little longer, Oh, Lord, let me tell you that the feeling's getting stronger.  And it's six in the morning, gave me no warning; I had to be on my way. Well there's trucks all a-passing me, and the lights are all flashing, I'm on my way home from your place.  And now the sun's coming up, I'm riding with Lady Luck, freeway cars and trucks, Stars beginning to fade, and I lead the parade Just a-wishing I'd stayed a little longer, Oh, Lord, let me tell you that the feeling's getting stronger.  And my time went so quickly, I went lickety-splickly out to my old '55 As I pulled away slowly, feeling so holy, God knows, I was feeling alive.  Now the sun's coming up, I'm riding with Lady Luck, Freeway
# ...

# %% [markdown]
# ## Synthesizing
# Create a script using your two functions above to scrape all of the song lyrics for a given artist.

# %%
#Use this block for your code!

# %%
def get_songs(artist_url):
    
    html_page = requests.get(artist_url) #Make a get request to retrieve the page
    soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing


    #The example from our lecture/reading
    albums = soup.find_all("div", class_="album")
    data = [] #Create a storage container
    for album_n in range(len(albums)):
        #On the last album, we won't be able to look forward
        if album_n == len(albums)-1:
            cur_album = albums[album_n]
            album_songs = cur_album.findNextSiblings('a')
            for song in album_songs:
                page = song.get('href')
                title = song.text
                album = cur_album.text
                data.append((title, page, album))
        else:
            cur_album = albums[album_n]
            next_album = albums[album_n+1]
            saca = cur_album.findNextSiblings('a') #songs after current album
            sbna = next_album.findPreviousSiblings('a') #songs before next album
            album_songs = [song for song in saca if song in sbna] #album songs are those listed after the current album but before the next one!
            for song in album_songs:
                page = song.get('href')
                title = song.text
                album = cur_album.text
                lyrics=0
                if page !=None:
                    lyrics= get_lyrics(page.replace('..',''))
                data.append((title, page, album,lyrics))
                print(title,page,album,lyrics)
    return data

# %%
def get_lyrics(page):
    new_link='https://www.azlyrics.com'+page
    html_page = requests.get(new_link)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    lyrics=soup.find(class_="col-xs-12 col-lg-8 text-center",)
    lyrics2=lyrics.findAll('div')
    lyrics3=lyrics2[6].text.replace('\n',' ').replace('\r',' ').strip()
    return lyrics3

# %%
maybe=get_songs('https://www.azlyrics.com/t/tomwaits.html')
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
maybe[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-59fa34d64902> in <module>()
# ----> 1 maybe[0]
#
# NameError: name 'maybe' is not defined

# %% [markdown]
# ## Visualizing
# Generate two bar graphs to compare lyrical changes for the artist of your chose. For example, the two bar charts could compare the lyrics for two different songs or two different albums.

# %%
#Use this block for your code!

# %% [markdown]
# ## Level - Up
#
# Think about how you structured the data from your web scraper. Did you scrape the entire song lyrics verbatim? Did you simply store the words and their frequency counts, or did you do something else entirely? List out a few different options for how you could have stored this data. What are advantages and disadvantages of each? Be specific and think about what sort of analyses each representation would lend itself to.

# %%
#Use this block for your code!

# %% [markdown]
# ## Summary

# %% [markdown]
# Congratulations! You've now practiced your Beautiful Soup knowledge!
